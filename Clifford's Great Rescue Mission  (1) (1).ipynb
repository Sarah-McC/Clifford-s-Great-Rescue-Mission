# %%
"""
DocString:
    A)Introduction:
    Clifford, a three-year-old goldendoodle, went missing while on a trip 
    with the Harris family in California's Tahoe Forest last month.
    Clifford is a beloved member of the Harris family and is deeply missed, 
    especially by the Harris’ youngest son, joe Harris. Joe Harris and 
    Clifford has a special bond because Clifford is Joe’s service dog.

    The Harris family has been distraught over Clifford’s disappearance and 
    have conducted an exhaustive search, posted flyers, and maintained a 
    Facebook page, but have yet to receive a single lead. The purpose of this
    game is to solve clues to figure out where Clifford may have wandered off
    and get him reunited with the Harris family. 

    B) Known Bugs and/or Errors:   
    None.
    
    """

#Needed for codes to function within the game
from random import randrange
import time
import sys

#Ascii art
print('''

  _, _,  _ __, __,  _, __, __,  _,    _, __, __,  _, ___
 / ` |   | |_  |_  / \ |_) | \ (_    / _ |_) |_  /_\  | 
 \ , | , | |   |   \ / | \ |_/ , )   \ / | \ |   | |  | 
  ~  ~~~ ~ ~   ~    ~  ~ ~ ~    ~     ~  ~ ~ ~~~ ~ ~  ~ 
                                                        
 __, __,  _,  _, _,_ __,
 |_) |_  (_  / ` | | |_ 
 | \ |   , ) \ , | | |  
 ~ ~ ~~~  ~   ~  `~' ~~~   ''')

print("""

          _,_
       (;;;)              ,
    ,__/a /;\            (;)
    (__   |;| _         //
     '--. \;/;;)_____ (;;)
        @\(,;)'      '`/
         (;;)          |
           \  _____\   /
          //||    \ \ |
         || ||     ||||
        (;;(;;)   (;(;;)
        ((_((_)  ((_((_)
 
                                        """)

#Prompt user to input name
user_name=input(prompt= "Hey there, what is your name?\t")

#Prompt user to press enter
User_name=input(f"""
Nice to meet you {user_name}! I am so excited to hear you are a part of the 
Animal Rescue Squad! 
please press enter to proceed\n""")

answer= input(f"""As a member of the Animal Rescue Squad you will be assigned 
the mission: Clifford's Great Rescue.

This mission requires you to use your intuituion to figure out where Joe's 
service dog,Clifford, may have wandered off.
 Press enter to proceed\n""")

#Figuring out how users might respond
answer_A = ["A", "a"]
answer_B = ["B", "b"]
answer_C = ["C", "c"]
yes = ["Y", "y", "yes"]
no = ["N", "n", "no"]

#Cutting down on duplication
required = ("\nUse only A, B,C, or D\n") 

#Define fail given user chooses wrong answer
def fail():
    print(f"""
    
    Sorry {user_name} your intuition was wrong this time. Better luck next 
    time!
    
    """)

    print(f"""
    
    {user_name} Would you like to play again? (Yes/No)""")

    replay = input(" > ")
    if replay in yes:
        ques_1()
    else:
        print(" Thanks for playing! ")

#define question 2 answer choice c. investigate calls
def investigate_calls():
    print (f"""
    Excellent choice {user_name}! All the new details you added to the
    flyers are now posted and are gaining attention from the locals. Now its 
    time to wait and investigate any callers that may have a lead on 
    Clifford's location.

    After completing your task you decide to ahead and take your lunch break
    at a nearby Subway. You are starving because you have not eaten since 
    arriving at work today.
  
    You are on your second bite until suddenly you receive a call from a man
    named Donald who claims Clifford is in his yard after jumping his gate.

    Do you go to Donald’s home address to pick up Clifford? 
    Yes/no""")

#Prompt user answer choices for Question 2 answer c.
    choice = input(">>> ")
    if choice in yes:
        print(f"""
        While on the way to Donald’s home address you receive a text from 
        Donald saying “Did you get the code?” You respond with, “What code?” 
     
        He texts again, this time with a string of numbers. You text back the 
        code to Donald thinking that it was a confirmation code to enter his 
        gate.
        
        It was actually a code to verify your gmail account.Unfortunately 
        {user_name} you have been hacked and lost the mission.""")
        fail()
    else:
        print(f"""
        Unfortunately {user_name} you were so hungry and in a hurry; 
        you ate too quickly causing you to choke and die on your Subway 
        Sandwich. 
        
        I’m sure it was worth it though! Maybe Clifford will forgive you 
        in the afterlife.""")
        fail()
        
        
        
#define Question 2 answer choice b. print flyers
def print_flyers():
    print ("""
    Good thinking, the Harris probably left out important details.
    What details about Clifford would you like to add on the flyer
    """ )

    #Prompt user to pick a letter for Question 2, answer choice b.
    time.sleep(1)
    print ("""  
    a. Add Clifford's breed
    b. Add Clifford's coat color
    c. Add Clifford's gender""")
   
   #Prompt user answer choice for Question 2, answer choice b.
    choice = input(">>> ")
    if choice in answer_A:
        fail()
    elif choice in answer_B:
        investigate_calls()
    elif choice in answer_C:
        investigate_calls()
    else:
        print (required)
        
        
#Question 2 answer choice a. investigate flyers
def investigate_flyers():
    print ("""Let’s go investigate the flyers the Harris family already put 
    up and see why they are not receiving any calls. 
    
    It appears it has rained, and the flyers are destroyed.
    What would you like to do next?\n""")

    #Prompt user to pick a letter for Question 2, answer choice a.
    time.sleep(1)
    print ("""  
    a. Print the flyers the Harris family left with you 
    b. Print new flyers with details you think are best 
    c. Don’t worry about it; the flyers probably won't work anyways""")
    
    #Prompt user answer choices for Question 2, answer choice a. 
    choice = input(">>> ")
    if choice in answer_A:
        fail()
    elif choice in answer_B:
        print_flyers()
    elif choice in answer_C:
        fail()
    else:
        print(required)        
        
        
#Prompt user Question 2
def ques_2():
    print (f"""\n
    Good choice {user_name}! Now you may go to work and check your 
    agenda for Clifford’s Great Rescue mission.
            
            {user_name}'s Agenda for the Day
         _______________________________________
    
Mission: Clifford's Great Resuce
Task: Investigate flyers
Message: Check neighborhood for lost dog flyers the Harris family has already 
posted and see if it is adequate.
_____________________________________________________________________________
Task: print flyers
Message: If flyers are not adequate, go see what details need to be added and 
post new ones. 
_____________________________________________________________________________
Task: Investigate calls
Message: If anyone calls about Clifford’s location, investigate the situation. 
_____________________________________________________________________________
 """)

    #Prompt user to pick a letter for Question 2
    time.sleep(1)
    print (f"""
  It looks like you have 3 tasks lined up.
  Which task would you like to complete first?

 a. Investigate flyers\n
 b. Print flyers\n
 c. Investigate calls\n
 """)
    
    #Prompt user Question 2 answer choices
    choice = input(">>> ") 
    if choice in answer_A:
        investigate_flyers()
    elif choice in answer_B:
        print_flyers()
    elif choice in answer_C:
        investigate_calls()
    else:
        print (required)
        
        
#Prompt bonus question if user chooses wrong answer choice 
def bonus():
    print(f"""
    You have one more chance to find Clifford!\n""")

    print("Why does Joe need Clifford?")
    print("""
        
        a. Clifford is first dog \n
        b. Clifford is his only friend \n
        c. Clifford is his service dog \n
        d. Clifford is his watchdog \n 
        
        """)
    
    response = input("type'a', 'b', 'c', or 'd' for your answer \n").casefold()
    
    #answer choices for Bonus Question
    if response == "a":
        fail()
    elif response == "b":
        fail()
    elif response == "c":
        ques_2()
    elif response == "d":
        fail()
    else:
        print(" Invalid ... please try agan! ")

#Prompt user trap 2 for Question 3 answer choice b. trap_setup
def trap_2():
  print(f"""
  While putting out treats for Clifford a curious bear smells it and 
  approaches you. You are startled and try to scare the bear away, but you 
  were unsucessful.
  Unfortunatley {user_name} you get eaten by a bear, Ouch!
  """)
  fail()

#Prompt user trap 3 for Question 3 answer choice b. trap_setup       
def trap_3():
  print(f"""
  Oh no {user_name}! It looks like you missed the main trail and are now lost 
  in the woods. At this point you are surviving off a Clifford's treats and 
  have lost cell service. 
  Unfortunately you become quite disoriented and end up 
  fainting. It looks like you hit your head pretty hard and are not ready to 
  successfully complete your mission. Better luck next time!
   """) 
  fail()
     
#define Question 3 answer choice a. Item_setup
def Item_setup():
    print ("""
    You bring Clifford’s bed and toys the Harris family bought him to 
    set up at the campsite. Your hope was that this would invite Clifford to 
    come back and feel more at home in the midst of the forest. 

    Your intuition was right! Unfortunately, other campers found Clifford and 
    thought he so cute so they decided to keep him. 
    You failed your mission, but good effort!
    """)
    fail()
    
    
#define Question 3 answer choice b. Trap_setup
def Trap_setup():
    print ("""Good thinking, I'm sure Clifford cant resist his favorite 
    treats!""" )
    
    #Prompt user to pick a letter for Question 3, answwer choice b.
    time.sleep(1)
    print ("""  
    a. Add Clifford's favorite treat
    b. Add Clifford's coat color
    c. Add Clifford's gender
    """)

    #Answer choices for Question 3, answer choice b. 
    choice = input(">>> ")
    if choice in answer_A:
        fail()
    elif choice in answer_B:
        trap_2()
    elif choice in answer_C:
        trap_3()
    else:
        print(required)
        

#define Question 3 answer choice c. hiking_trails
def hiking_trails():
    print ("""
    Good thinking, maybe you can retrack Clifford's tracks by following
    one of the trails back to the campsite that he was last seen.
    Which hiking trail would you like to take?
    """ )

    #Prompt user to pick a letter for Question 3, answer choice c.
    time.sleep(1)
    print ("""  
    a. The Python Trail
    b. The Java Trail 
    c. The Steve Jobs trail
    """)

    #Answer choices for Question 3, answer choice c. 
    choice = input(">>> ")
    if choice in answer_A:
        print(f"""
        You follow the trail and trip over a tree stump. Unfortunately 
        {user_name}, you break your leg, and no one can hear you except a 
        bear. 
        The bear decides you will make a nice meal. You die and fail the 
        mission.
        """)
        fail()
        
    elif choice in answer_B:
        print(f"""
        You follow the trail and you end up at a creek. Unfortunately 
        {user_name}, this was the incorrect trail and you are eaten by a bear.
         """)
        fail()
        
    elif choice in answer_C:
        print(f"""
        Congrats {user_name}! You followed the right trail and reached the 
        campsite. You see Clifford and he seems incredibly happy to see you. 
        You call the Harris family and tell them the good news.
    
        Clifford hops in your car ready to go home. You reach the Harris 
        household and Clifford is finally reunited with Joe!

        Congrats on winning the game. You are a natural on the Animal Rescue 
        Squad!""")
        print("""
             .''.      .        *''*    :_\/_:     . 
      :_\/_:   _\(/_  .:.*_\/_*   : /\ :  .'.:.'.
  .''.: /\ :   ./)\   ':'* /\ * :  '..'.  -=:o:=-
 :_\/_:'.:::.    ' *''*    * '.\'/.' _\(/_'.':'.'
 : /\ : :::::     *_\/_*     -= o =-  /)\    '  *
  '..'  ':::'     * /\ *     .'/.\'.   '
      *            *..*         :
     *                 
__          ___                       _ _ _ 
\ \        / (_)                     | | | |
 \ \  /\  / / _ _ __  _ __   ___ _ __| | | |
  \ \/  \/ / | | '_ \| '_ \ / _ \ '__| | | |
   \  /\  /  | | | | | | | |  __/ |  |_|_|_|
    \/  \/   |_|_| |_|_| |_|\___|_|  (_|_|_)
                          
                         
               
     .''.      .        *''*    :_\/_:     . 
      :_\/_:   _\(/_  .:.*_\/_*   : /\ :  .'.:.'.
  .''.: /\ :   ./)\   ':'* /\ * :  '..'.  -=:o:=-
 :_\/_:'.:::.    ' *''*    * '.\'/.' _\(/_'.':'.'
 : /\ : :::::     *_\/_*     -= o =-  /)\    '  *
  '..'  ':::'     * /\ *     .'/.\'.   '
      *            *..*         :
            *
        *
                 
                         
                        """)
        
    else:
        print(required)        
        
        
#Prompt user Question 3
def ques_3():
    print (f"""\n
    Good choice {user_name}! Now you may go to work and check your 
    agenda for Clifford’s Great Rescue mission.

                    {user_name}'s Agenda for the Day
                 _______________________________________

Mission: Clifford's Great Rescue
Task: Set up Clifford’s items 
Message: Set up bed and toys Clifford had while he was staying at the Harris
household. 
_____________________________________________________________________________
Task: Set up a trap and watch for Clifford’s return
Message: Put Clifford’s favorite meal: a mix of kibble, chicken, and rice.   
____________________________________________________________________________
Task: Take hiking trail back to the campsite Clifford was last seen
Message: Choose the appropriate trail leading to the campsite
""")
    
  #Prompt user to pick a letter for Question3
    time.sleep(1)
    print(f"""
    It looks like you have 3 tasks lined up.
    Which task would you like to complete first?

a. Set up Clifford’s items
b. Set up a trap and watch for Clifford’s return
c. Take hiking tails""")
    
    #Prompt user Question3 answer choices
    choice = input(">>> ") 
    if choice in answer_A:
        Item_setup()
    elif choice in answer_B:
        Trap_setup()
    elif choice in answer_C:
        hiking_trails()
    else:
        print(required)
        
 #Prompt user Question1       
def ques_1():
   question1 = """
    Before you begin solving, choose 1 out of the 4 scenarios.
    Keep in mind that your objective is to find Clifford.

    So choose wisely which scenario you want to play
    or you may end the game sooner than expected.\n"""

    #Prompt user to pick a letter for Question1
   options1 = """
   a. Advertise on the internet\n
   b. Go to the animal shelter\n
   c. Put up flyers\n
   d. Go back to the campsite\n"""
   print(question1)
   print(options1)
   response = input("type'a', 'b', 'c', or 'd' for your answer \n").casefold()
    
    #Question1 answer choices
   if response == "a":
        print("""
        That answer is incorrect. 
        Try your luck again with a bonus question.""")
        bonus()
   elif response == "b":
        print("""That answer is incorrect. 
        Try your luck again with a bonus question.""")
        bonus()
   elif response == "c":
        ques_2()
   elif response == "d":
        ques_3()
   else:
        print("Invalid input... Please try again!")

#Prompt user Question 1 if user wants to play again
ques_1()
# Out:
#   _, _,  _ __, __,  _, __, __,  _,    _, __, __,  _, ___
#  / ` |   | |_  |_  / \ |_) | \ (_    / _ |_) |_  /_\  |
#  \ , | , | |   |   \ / | \ |_/ , )   \ / | \ |   | |  |
#   ~  ~~~ ~ ~   ~    ~  ~ ~ ~    ~     ~  ~ ~ ~~~ ~ ~  ~
#
#  __, __,  _,  _, _,_ __,
#  |_) |_  (_  / ` | | |_
#  | \ |   , ) \ , | | |
#  ~ ~ ~~~  ~   ~  `~' ~~~
#
#
#           _,_
#        (;;;)              ,
#     ,__/a /;\            (;)
#     (__   |;| _         //
#      '--. \;/;;)_____ (;;)
#         @\(,;)'      '`/
#          (;;)          |
#            \  _____\   /
#           //||    \ \ |
#          || ||     ||||
#         (;;(;;)   (;(;;)
#         ((_((_)  ((_((_)
